# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_8 = pd.read_csv('Data_8.txt', sep=" ", header=None)

# %%
data_8.columns = ["vert", "vol"]

# %%
data_8.hist(column='vol', bins = 22, range=[3.5, 4.1]);

# %%
data_10 = pd.read_csv('Data_10.txt', sep=" ", header=None)

# %%
data_10.columns = ["vert", "vol"]

# %%
data_10.hist(column='vol', bins = 16, range=[3.5, 4.1]);

# %%
data_12 = pd.read_csv('Data_12.txt', sep=" ", header=None)

# %%
data_12.columns = ["vert", "vol"]

# %%
data_12.hist(column='vol', bins = 15, range=[3.5, 4.1]);

# %%
data_20 = pd.read_csv('Data_20.txt', sep=" ", header=None)

# %%
data_20.columns = ["vert", "vol"]

# %%
data_20.hist(column='vol', bins = 17, range=[3.5, 4.1]);
